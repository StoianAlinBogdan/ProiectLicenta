# %%
from qiskit import Aer, QuantumCircuit
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 5]

# %%
qc = QuantumCircuit(8)
qc.h(range(8))
qc.measure_all()
qc.draw(output='mpl')

# %%
sim = Aer.get_backend('aer_simulator')
result = sim.run(qc, shots=100000).result()
counts = result.get_counts()
len(counts)
# Out:
# 256

# %%
plt.bar([int(x, 2) for x in counts.keys()], counts.values(), width=5)
plt.show()

# %%
#from qiskit.circuit.library import UniformDistribution
from qiskit_finance.circuit.library import UniformDistribution
qc2 = UniformDistribution(8)
result2 = sim.run(qc2, shots=100000).result()
counts2 = result2.get_counts()
plt.bar([int(x, 2) for x in counts2.keys()], counts2.values(), width=5)
plt.show()
# Out:
# C:\Users\STOIAN~1\AppData\Local\Temp/ipykernel_9532/3238603244.py:2: DeprecationWarning: `UniformDistribution` is deprecated as of version 0.17.0 and will be removed no earlier than 3 months after the release date. It moved to qiskit_finance.circuit.library.UniformDistribution.
#   qc2 = UniformDistribution(8)
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# C:\Users\STOIAN~1\AppData\Local\Temp/ipykernel_9532/3238603244.py in <module>
#       2 qc2 = UniformDistribution(8)
#       3 result2 = sim.run(qc2, shots=100000).result()
# ----> 4 counts2 = result2.get_counts()
#       5 plt.bar([int(x, 2) for x in counts2.keys()], counts2.values(), width=5)
#       6 plt.show()
#
# ~\AppData\Roaming\Python\Python39\site-packages\qiskit\result\result.py in get_counts(self, experiment)
#     298                 dict_list.append(statevector.Statevector(vec).probabilities_dict(decimals=15))
#     299             else:
# --> 300                 raise QiskitError(f'No counts for experiment "{repr(key)}"')
#     301
#     302         # Return first item of dict_list if size is 1
#
# QiskitError: 'No counts for experiment "0"'
